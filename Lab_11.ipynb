# %% [markdown]
# <a href="https://colab.research.google.com/github/Avika24/Lab1_AlgorithmBasics/blob/main/Lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Travelling Salesman Problem using Dynamic Programming.
# Problem Description:
# Given a set of cities and distances, find the shortest possible route that visits each city once and returns to the starting city.

# %% [markdown]
# #Theory
# TSP uses dynamic programming with bit masking. Store results of visited subsets to reduce repeated work.
#
# ## Algorithm
# 1. Start from source city
# 2. Mark visited cities using bit mask
# 3. Try all unvisited cities
# 4. Choose minimum cost path
# 5. Return to source city

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost

        dp[city][mask] = ans
        return ans

    return visit(0, 1)

# %%
graph = [
[0, 10, 15, 20],
[10, 0, 35, 25],
[15, 35, 0, 30],
[20, 25, 30, 0]
]

print("Minimum travelling cost:", tsp(graph))
# Out:
# Minimum travelling cost: 80

# %%
import sys

def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]
    parent = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost
                    parent[city][mask] = next_city

        dp[city][mask] = ans
        return ans

    min_cost = visit(0, 1)

    path = []
    mask = 1
    city = 0

    while True:
        path.append(city)
        next_city = parent[city][mask]
        if next_city == -1:
            break
        mask |= (1<<next_city)
        city = next_city

    path.append(0)

    return min_cost, path


graph = [
[0, 10, 15, 20],
[10, 0, 35, 25],
[15, 35, 0, 30],
[20, 25, 30, 0]
]

cost, path = tsp(graph)

print("Minimum travelling cost:", cost)
print("Path:", " -> ".join("A"+str(i) for i in path))
# Out:
# Minimum travelling cost: 80
# Path: A0 -> A1 -> A3 -> A2 -> A0

# %%
import sys

def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                ans = min(ans, new_cost)

        dp[city][mask] = ans
        return ans

    return visit(0, 1)


n = int(input("Enter number of cities: "))

graph = []
print("Enter adjacency matrix:")

for _ in range(n):
    row = list(map(int, input().split()))
    graph.append(row)

print("Minimum travelling cost:", tsp(graph))
# Out:
# Enter number of cities: 4
# Enter adjacency matrix:
# 0 10 15 20
# 10 0 35 25
# 15 35 0 30
# 20 25 30 0
# Minimum travelling cost: 80

# %%
import sys

def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                ans = min(ans, new_cost)

        dp[city][mask] = ans
        return ans

    return visit(0, 1)


graph1 = [
[0, 10, 15, 20],
[10, 0, 35, 25],
[15, 35, 0, 30],
[20, 25, 30, 0]
]

graph2 = [
[0, 29, 20, 21, 16],
[29, 0, 15, 17, 28],
[20, 15, 0, 28, 39],
[21, 17, 28, 0, 13],
[16, 28, 39, 13, 0]
]

print("4 cities cost:", tsp(graph1))
print("5 cities cost:", tsp(graph2))
# Out:
# 4 cities cost: 80
# 5 cities cost: 81

# %% [markdown]
# # Exercise
# 1. Print path of cities visited
# 2. Take graph input from user
# 3. Test with different number of cities
